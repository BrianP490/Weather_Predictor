# %%
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Histplot

# %%
sns.histplot(data=tips, x="day", y="total_bill", kde=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(data=tips, x="day", kde=True)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", kde=True, stat="density", bins=40)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(data=tips, x="tip", orient='v')
# Out:
# c:\Users\brian\miniconda3\envs\WP_env\lib\site-packages\seaborn\_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <Axes: xlabel='tip'>

# %%
sns.boxplot(data=tips, x="tip", hue="sex")
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(data=tips, x="day", y="tip", orient='v', hue='size', palette="rocket_r")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# plt.figure(figsize=(12, 7))
sns.boxplot(data=tips, x="day", y="tip", orient='v', hue='smoker', palette="YlOrBr")
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Strip Plot

# %%
sns.stripplot(data=tips, x="size")
# Out:
# <Axes: xlabel='size'>

# %% [markdown]
# ### Without Dodge=True

# %%
sns.stripplot(data=tips, x="size", y="total_bill", hue="sex")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ### With Dodge=True

# %%
sns.stripplot(data=tips, x="size", y="total_bill", hue="sex", dodge=True, palette="viridis")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(data=tips, x="tip", y="total_bill", palette="Spectral")

# %%
sns.jointplot(data=tips, x="tip", y="total_bill", kind="hist", hue="sex")

# %% [markdown]
# ## Pair Plot

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dropped=titanic.drop(columns=["class", "embarked","who","deck","embark_town","alive"], axis=1)
dropped
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  adult_male  alone
# 0           0       3    male  22.0      1      0   7.2500        True  False
# 1           1       1  female  38.0      1      0  71.2833       False  False
# 2           1       3  female  26.0      0      0   7.9250       False   True
# 3           1       1  female  35.0      1      0  53.1000       False  False
# 4           0       3    male  35.0      0      0   8.0500        True   True
# ..        ...     ...     ...   ...    ...    ...      ...         ...    ...
# 886         0       2    male  27.0      0      0  13.0000        True   True
# 887         1       1  female  19.0      0      0  30.0000       False   True
# 888         0       3  female   NaN      1      2  23.4500       False  False
# 889         1       1    male  26.0      0      0  30.0000        True   True
# 890         0       3    male  32.0      0      0   7.7500        True   True
#
# [891 rows x 9 columns]

# %%
sns.pairplot(data=titanic)

# %% [markdown]
# ## Heat Map

# %%
iris= sns.load_dataset("iris")

# %%
dropped=iris.drop(columns=["species"], axis=1)
dropped
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.clustermap(data=dropped)
