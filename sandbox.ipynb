# %% [markdown]
# # Sandbox

# %% [markdown]
# ## Imports

# %%
from importlib.metadata import version
import pandas as pd
import numpy as np
import seaborn as sn
from pathlib import Path
import os

# %% [markdown]
# ## Data Preparation

# %%
# Login using e.g. `huggingface-cli login` to access this dataset
df = pd.read_csv("hf://datasets/MaxPrestige/CA_Weather_Fire_Dataset_Cleaned/Data/CA_Weather_Fire_Dataset_Cleaned.csv")

# %%
df
# Out:
#        DAY_OF_YEAR  MONTH    YEAR  SEASON  PRECIPITATION  \
# 0              1.0    1.0  1984.0     1.0            0.0
# 1              2.0    1.0  1984.0     1.0            0.0
# 2              3.0    1.0  1984.0     1.0            0.0
# 3              4.0    1.0  1984.0     1.0            0.0
# 4              5.0    1.0  1984.0     1.0            0.0
# ...            ...    ...     ...     ...            ...
# 14983          8.0    1.0  2025.0     1.0            0.0
# 14984          9.0    1.0  2025.0     1.0            0.0
# 14985         10.0    1.0  2025.0     1.0            0.0
# 14986         11.0    1.0  2025.0     1.0            0.0
# 14987         12.0    1.0  2025.0     1.0            0.0
#
#        LAGGED_PRECIPITATION  AVG_WIND_SPEED  LAGGED_AVG_WIND_SPEED  \
# 0                       0.0            4.70               4.700000
# 1                       0.0            5.59               5.145000
# 2                       0.0            5.37               5.220000
# 3                       0.0            4.70               5.090000
# 4                       0.0            5.14               5.100000
# ...                     ...             ...                    ...
# 14983                   0.0           10.51               6.485714
# 14984                   0.0            4.92               6.550000
# 14985                   0.0            3.58               6.327143
# 14986                   0.0             NaN               6.561667
# 14987                   0.0             NaN               7.068000
#
#        WIND_TEMP_RATIO  MIN_TEMP  TEMP_RANGE  FIRE_START_DAY  MAX_TEMP
# 0             0.059494      51.0        28.0             0.0      79.0
# 1             0.078732      46.0        25.0             0.0      71.0
# 2             0.076714      47.0        23.0             0.0      70.0
# 3             0.061842      45.0        31.0             0.0      76.0
# 4             0.069459      49.0        25.0             0.0      74.0
# ...                ...       ...         ...             ...       ...
# 14983         0.143973      53.0        20.0             0.0      73.0
# 14984         0.072353      46.0        22.0             0.0      68.0
# 14985         0.051143      46.0        24.0             0.0      70.0
# 14986              NaN      46.0        20.0             0.0      66.0
# 14987              NaN      46.0        23.0             0.0      69.0
#
# [14988 rows x 13 columns]

# %%
WEATHER_PATH_ORIGINAL = Path("./Data/CA_Weather_Fire_Dataset_1984-2025.csv")     # Set the data source path
WEATHER_DATA_CLEAN="CA_Weather_Fire_Dataset_Cleaned.csv"
WEATHER_DATA_CLEAN_PATH = Path("./Data") / WEATHER_DATA_CLEAN

# %%
# Replace with the actual path to your CSV file
data = pd.read_csv(WEATHER_PATH_ORIGINAL, sep=',',header=0)

test_df = data.copy()

# %%
test_df.shape
# Out:
# (14988, 14)

# %%
test_df.head(5)
# Out:
#          DATE  PRECIPITATION  MAX_TEMP  MIN_TEMP  AVG_WIND_SPEED  \
# 0  1984-01-01            0.0      79.0      51.0            4.70
# 1  1984-01-02            0.0      71.0      46.0            5.59
# 2  1984-01-03            0.0      70.0      47.0            5.37
# 3  1984-01-04            0.0      76.0      45.0            4.70
# 4  1984-01-05            0.0      74.0      49.0            5.14
#
#    FIRE_START_DAY  YEAR  TEMP_RANGE  WIND_TEMP_RATIO  MONTH  SEASON  \
# 0           False  1984        28.0         0.059494      1  Winter
# 1           False  1984        25.0         0.078732      1  Winter
# 2           False  1984        23.0         0.076714      1  Winter
# 3           False  1984        31.0         0.061842      1  Winter
# 4           False  1984        25.0         0.069459      1  Winter
#
#    LAGGED_PRECIPITATION  LAGGED_AVG_WIND_SPEED  DAY_OF_YEAR
# 0                   0.0                  4.700            1
# 1                   0.0                  5.145            2
# 2                   0.0                  5.220            3
# 3                   0.0                  5.090            4
# 4                   0.0                  5.100            5

# %%
test_df.tail(5)
# Out:
#              DATE  PRECIPITATION  MAX_TEMP  MIN_TEMP  AVG_WIND_SPEED  \
# 14983  2025-01-08            0.0      73.0      53.0           10.51
# 14984  2025-01-09            0.0      68.0      46.0            4.92
# 14985  2025-01-10            0.0      70.0      46.0            3.58
# 14986  2025-01-11            0.0      66.0      46.0             NaN
# 14987  2025-01-12            0.0      69.0      46.0             NaN
#
#        FIRE_START_DAY  YEAR  TEMP_RANGE  WIND_TEMP_RATIO  MONTH  SEASON  \
# 14983           False  2025        20.0         0.143973      1  Winter
# 14984           False  2025        22.0         0.072353      1  Winter
# 14985           False  2025        24.0         0.051143      1  Winter
# 14986           False  2025        20.0              NaN      1  Winter
# 14987           False  2025        23.0              NaN      1  Winter
#
#        LAGGED_PRECIPITATION  LAGGED_AVG_WIND_SPEED  DAY_OF_YEAR
# 14983                   0.0               6.485714            8
# 14984                   0.0               6.550000            9
# 14985                   0.0               6.327143           10
# 14986                   0.0               6.561667           11
# 14987                   0.0               7.068000           12

# %%
# Convert SEASON column to float
season_map = {'Winter': 1.0, 'Spring': 2.0, 'Summer': 3.0, 'Fall': 4.0}
test_df['SEASON'] = test_df['SEASON'].map(season_map)

# %%
# Convert int to floats
test_df[['FIRE_START_DAY', 'YEAR', 'MONTH', 'DAY_OF_YEAR']] = test_df[['FIRE_START_DAY', 'YEAR', 'MONTH', 'DAY_OF_YEAR']].astype(float)

# %%
test_df.drop(columns=['DATE'], inplace=True)

# %%
test_df.head()
# Out:
#    PRECIPITATION  MAX_TEMP  MIN_TEMP  AVG_WIND_SPEED  FIRE_START_DAY    YEAR  \
# 0            0.0      79.0      51.0            4.70             0.0  1984.0
# 1            0.0      71.0      46.0            5.59             0.0  1984.0
# 2            0.0      70.0      47.0            5.37             0.0  1984.0
# 3            0.0      76.0      45.0            4.70             0.0  1984.0
# 4            0.0      74.0      49.0            5.14             0.0  1984.0
#
#    TEMP_RANGE  WIND_TEMP_RATIO  MONTH  SEASON  LAGGED_PRECIPITATION  \
# 0        28.0         0.059494    1.0     1.0                   0.0
# 1        25.0         0.078732    1.0     1.0                   0.0
# 2        23.0         0.076714    1.0     1.0                   0.0
# 3        31.0         0.061842    1.0     1.0                   0.0
# 4        25.0         0.069459    1.0     1.0                   0.0
#
#    LAGGED_AVG_WIND_SPEED  DAY_OF_YEAR
# 0                  4.700          1.0
# 1                  5.145          2.0
# 2                  5.220          3.0
# 3                  5.090          4.0
# 4                  5.100          5.0

# %%
test_df.tail()
# Out:
#        PRECIPITATION  MAX_TEMP  MIN_TEMP  AVG_WIND_SPEED  FIRE_START_DAY  \
# 14983            0.0      73.0      53.0           10.51             0.0
# 14984            0.0      68.0      46.0            4.92             0.0
# 14985            0.0      70.0      46.0            3.58             0.0
# 14986            0.0      66.0      46.0             NaN             0.0
# 14987            0.0      69.0      46.0             NaN             0.0
#
#          YEAR  TEMP_RANGE  WIND_TEMP_RATIO  MONTH  SEASON  \
# 14983  2025.0        20.0         0.143973    1.0     1.0
# 14984  2025.0        22.0         0.072353    1.0     1.0
# 14985  2025.0        24.0         0.051143    1.0     1.0
# 14986  2025.0        20.0              NaN    1.0     1.0
# 14987  2025.0        23.0              NaN    1.0     1.0
#
#        LAGGED_PRECIPITATION  LAGGED_AVG_WIND_SPEED  DAY_OF_YEAR
# 14983                   0.0               6.485714          8.0
# 14984                   0.0               6.550000          9.0
# 14985                   0.0               6.327143         10.0
# 14986                   0.0               6.561667         11.0
# 14987                   0.0               7.068000         12.0

# %%
test_df.shape
# Out:
# (14988, 13)

# %%
new_order = ['DAY_OF_YEAR', 'MONTH', 'YEAR', 'SEASON', 'PRECIPITATION', 'LAGGED_PRECIPITATION', 'AVG_WIND_SPEED', 'LAGGED_AVG_WIND_SPEED', 'WIND_TEMP_RATIO', 'MIN_TEMP', 'TEMP_RANGE', 'FIRE_START_DAY', 'MAX_TEMP']  # Put your desired column names here, leaving the target on the furthest on the right
test_df = test_df[new_order]

# %%
prep_greater_than_zero_2 = test_df[test_df['PRECIPITATION'] > 0.0]

# %%
prep_greater_than_zero_2.shape
# Out:
# (4939, 13)

# %%
prep_greater_than_zero_2.head(20)
# Out:
#      DAY_OF_YEAR  MONTH    YEAR  SEASON  PRECIPITATION  LAGGED_PRECIPITATION  \
# 15          16.0    1.0  1984.0     1.0           0.39                  0.39
# 40          41.0    2.0  1984.0     1.0           0.01                  0.01
# 73          74.0    3.0  1984.0     2.0           0.14                  0.14
# 96          97.0    4.0  1984.0     2.0           0.87                  0.87
# 108        109.0    4.0  1984.0     2.0           0.04                  0.04
# 109        110.0    4.0  1984.0     2.0           0.10                  0.14
# 117        118.0    4.0  1984.0     2.0           0.15                  0.15
# 227        228.0    8.0  1984.0     3.0           0.29                  0.29
# 253        254.0    9.0  1984.0     4.0           0.02                  0.02
# 254        255.0    9.0  1984.0     4.0           0.02                  0.04
# 268        269.0    9.0  1984.0     4.0           0.05                  0.05
# 289        290.0   10.0  1984.0     4.0           0.07                  0.07
# 290        291.0   10.0  1984.0     4.0           0.21                  0.28
# 312        313.0   11.0  1984.0     4.0           0.09                  0.09
# 316        317.0   11.0  1984.0     4.0           0.01                  0.10
# 317        318.0   11.0  1984.0     4.0           0.15                  0.25
# 322        323.0   11.0  1984.0     4.0           0.01                  0.17
# 328        329.0   11.0  1984.0     4.0           0.93                  0.94
# 332        333.0   11.0  1984.0     4.0           0.05                  0.98
# 337        338.0   12.0  1984.0     1.0           0.06                  0.11
#
#      AVG_WIND_SPEED  LAGGED_AVG_WIND_SPEED  WIND_TEMP_RATIO  MIN_TEMP  \
# 15             6.71               6.007143         0.122000      45.0
# 40            11.18               6.871429         0.172000      51.0
# 73            12.30               8.597143         0.189231      56.0
# 96            10.51               9.522857         0.159242      53.0
# 108           10.29               7.925714         0.155909      55.0
# 109           19.91              10.035714         0.311094      55.0
# 117            8.50              11.472857         0.132812      50.0
# 227            7.83               8.372857         0.097875      65.0
# 253            7.38               7.318571         0.088916      73.0
# 254            5.82               7.191429         0.077600      71.0
# 268            8.05               7.922857         0.103205      63.0
# 289            8.28               9.235714         0.108947      57.0
# 290            9.84               9.618571         0.149091      55.0
# 312           14.09               8.371429         0.213485      58.0
# 316            7.61               8.468571         0.113582      51.0
# 317            9.84               8.564286         0.149091      58.0
# 322            5.14               6.741429         0.085667      54.0
# 328            7.83               6.740000         0.135000      49.0
# 332            8.95               7.732857         0.151695      50.0
# 337            7.61               6.615714         0.126833      52.0
#
#      TEMP_RANGE  FIRE_START_DAY  MAX_TEMP
# 15         10.0             0.0      55.0
# 40         14.0             0.0      65.0
# 73          9.0             0.0      65.0
# 96         13.0             0.0      66.0
# 108        11.0             1.0      66.0
# 109         9.0             0.0      64.0
# 117        14.0             0.0      64.0
# 227        15.0             0.0      80.0
# 253        10.0             1.0      83.0
# 254         4.0             0.0      75.0
# 268        15.0             0.0      78.0
# 289        19.0             0.0      76.0
# 290        11.0             0.0      66.0
# 312         8.0             0.0      66.0
# 316        16.0             0.0      67.0
# 317         8.0             0.0      66.0
# 322         6.0             0.0      60.0
# 328         9.0             0.0      58.0
# 332         9.0             0.0      59.0
# 337         8.0             0.0      60.0

# %%
# Ensure the directory exists
os.makedirs(WEATHER_DATA_CLEAN_PATH.parent, exist_ok=True)

# %%
test_df.to_csv(WEATHER_DATA_CLEAN_PATH, index=False)

# %%
print(test_df.columns.tolist())
# output
['DAY_OF_YEAR', 'MONTH', 'YEAR', 'SEASON', 'PRECIPITATION', 'LAGGED_PRECIPITATION', 'AVG_WIND_SPEED', 'LAGGED_AVG_WIND_SPEED', 'WIND_TEMP_RATIO', 'MIN_TEMP', 'TEMP_RANGE', 'FIRE_START_DAY', 'MAX_TEMP']
# Out:
# ['DAY_OF_YEAR', 'MONTH', 'YEAR', 'SEASON', 'PRECIPITATION', 'LAGGED_PRECIPITATION', 'AVG_WIND_SPEED', 'LAGGED_AVG_WIND_SPEED', 'WIND_TEMP_RATIO', 'MIN_TEMP', 'TEMP_RANGE', 'FIRE_START_DAY', 'MAX_TEMP']

# %%
data2 = pd.read_csv(WEATHER_DATA_CLEAN_PATH, sep=',',header=0)

# %%
data2.head()
# Out:
#    DAY_OF_YEAR  MONTH    YEAR  SEASON  PRECIPITATION  LAGGED_PRECIPITATION  \
# 0          1.0    1.0  1984.0     1.0            0.0                   0.0
# 1          2.0    1.0  1984.0     1.0            0.0                   0.0
# 2          3.0    1.0  1984.0     1.0            0.0                   0.0
# 3          4.0    1.0  1984.0     1.0            0.0                   0.0
# 4          5.0    1.0  1984.0     1.0            0.0                   0.0
#
#    AVG_WIND_SPEED  LAGGED_AVG_WIND_SPEED  WIND_TEMP_RATIO  MIN_TEMP  \
# 0            4.70                  4.700         0.059494      51.0
# 1            5.59                  5.145         0.078732      46.0
# 2            5.37                  5.220         0.076714      47.0
# 3            4.70                  5.090         0.061842      45.0
# 4            5.14                  5.100         0.069459      49.0
#
#    TEMP_RANGE  FIRE_START_DAY  MAX_TEMP
# 0        28.0             0.0      79.0
# 1        25.0             0.0      71.0
# 2        23.0             0.0      70.0
# 3        31.0             0.0      76.0
# 4        25.0             0.0      74.0
